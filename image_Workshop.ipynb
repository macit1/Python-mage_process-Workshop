# %% [markdown]
# # Image Manipulation Workshop
#
# >
#     -What is an image data for computer?
#     -Which libraries are using to read images?
#     -How to manipulate and do preprocessing fro image data?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Option 1 - Main modules package:
# ```python
# pip install opencv-python
# ```
# Option 2 - Full package (contains both main modules and contrib/extra modules):
# ```python
# pip install opencv-contrib-python
# ```

# %% [markdown]
# **İmport Libraries**

# %% [markdown]
# RGB Layers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Distribution

# %% [markdown]
# Edge Detection

# %% [markdown]
# Show Video

# %% [markdown]
# ![image.png](attachment:image.png)
